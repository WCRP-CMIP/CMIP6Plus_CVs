# %%
import cmipld
import sys , os,    re,  glob, json
import pprint

# %%
# data = {        "piClim-370":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "CHEM",
#                 "BGC"
#             ],
#             "description": "",
#             "end":"2080",
#             "experiment":"pre-industrial climatological SSTs and forcing, but with 2050 anthropogenic emissions from SSP3-7.0.",
#             "experiment_id":"piClim-370",
#             "min_number_yrs_per_sim": 30,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "piControl"
#             ],
#             "required_model_components":[
#                 "AGCM",
#                 "AER"
#             ],
#             "start": "2050",
#             "sub_experiment_id":[
#                 "none"
#             ]
#         },
#         "piClim-370-126aer":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "CHEM",
#                 "BGC"
#             ],
#             "description": "",
#             "end":"2080",
#             "experiment":"pre-industrial climatological SSTs and forcing, but with 2050 anthropogenic emissions. Aerosol and precursor emissions are taken from SSP1-2.6, while all other anthropogenic emissions follow SSP3-7.0.",
#             "experiment_id":"piClim-370-126aer",
#             "min_number_yrs_per_sim": 30,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "piControl"
#             ],
#             "required_model_components":[
#                 "AGCM",
#                 "AER"
#             ],
#             "start": "2050",
#             "sub_experiment_id":[
#                 "none"
#             ]
#         },
#         "piClim-370-eas126aer":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "CHEM",
#                 "BGC"
#             ],
#             "description": "",
#             "end": "2080",
#             "experiment":"pre-industrial climatological SSTs and forcing, but with 2050 anthropogenic emissions. Aerosol and precursor emissions over East Asia are taken from SSP1-2.6, while all other anthropogenic emissions follow SSP3-7.0.",
#             "experiment_id":"piClim-370-eas126aer",
#             "min_number_yrs_per_sim": 30,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "piControl"
#             ],
#             "required_model_components":[
#                 "AGCM",
#                 "AER"
#             ],
#             "start": "2050",
#             "sub_experiment_id":[
#                 "none"
#             ]
#         },
#         "piClim-370-sas126aer":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "CHEM",
#                 "BGC"
#             ],
#             "description": "",
#             "end": "2080",
#             "experiment":"pre-industrial climatological SSTs and forcing, but with 2050 anthropogenic emissions. Aerosol and precursor emissions over South Asia are taken from SSP1-2.6, while all other anthropogenic emissions follow SSP3-7.0.",
#             "experiment_id":"piClim-370-sas126aer",
#             "min_number_yrs_per_sim": 30,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "piControl"
#             ],
#             "required_model_components":[
#                 "AGCM",
#                 "AER"
#             ],
#             "start":"2050",
#             "sub_experiment_id":[
#                 "none"
#             ]
#         },
#         "piClim-370-afr126aer":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "CHEM",
#                 "BGC"
#             ],
#             "description": "",
#             "end": "2080",
#             "experiment":"pre-industrial climatological SSTs and forcing, but with 2050 anthropogenic emissions. Aerosol and precursor emissions over Africa and the Middle East are taken from SSP1-2.6, while all other anthropogenic emissions follow SSP3-7.0.",
#             "experiment_id":"piClim-370-afr126aer",
#             "min_number_yrs_per_sim": 30,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "piControl"
#             ],
#             "required_model_components":[
#                 "AGCM",
#                 "AER"
#             ],
#             "start": "2050",
#             "sub_experiment_id":[
#                 "none"
#             ]
#         },
#         "piClim-370-nae126aer":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "CHEM",
#                 "BGC"
#             ],
#             "description": "",
#             "end": "2080",
#             "experiment":"pre-industrial climatological SSTs and forcing, but with 2050 anthropogenic emissions. Aerosol and precursor emissions over North America and Europe are taken from SSP1-2.6, while all other anthropogenic emissions follow SSP3-7.0.",
#             "experiment_id":"piClim-370-nae126aer",
#             "min_number_yrs_per_sim": 30,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "piControl"
#             ],
#             "required_model_components":[
#                 "AGCM",
#                 "AER"
#             ],
#             "start": "2050",
#             "sub_experiment_id":[
#                 "none"
#             ]
#         },
#         "piClim-370-126aer_nh3nox":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "CHEM",
#                 "BGC"
#             ],
#             "description": "",
#             "end": "2080",
#             "experiment":"pre-industrial climatological SSTs and forcing, but with 2050 anthropogenic emissions. Aerosol and precursor emissions, including NH3 and NOx, are taken from SSP1-2.6, while all other anthropogenic emissions follow SSP3-7.0.",
#             "experiment_id":"piClim-370-126aer_nh3nox",
#             "min_number_yrs_per_sim": 30,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "piControl"
#             ],
#             "required_model_components":[
#                 "AGCM",
#                 "AER"
#             ],
#             "start": "2050",
#             "sub_experiment_id":[
#                 "none"
#             ]
#         },
        
#         "ssp370-126aer":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "AER",
#                 "CHEM",
#                 "BGC"
#             ],
#             "description":"SSP3-7.0 anthropogenic emissions, but with anthropogenic aerosol and precursor emissions taken from SSP1-2.6.",
#             "end":"2051",
#             "experiment":"SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and precursor emissions",
#             "experiment_id":"ssp370-126aer",
#             "min_number_yrs_per_sim": 37,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "historical"
#             ],
#             "required_model_components":[
#                 "AOGCM"
#             ],
#             "start":"2015",
#             "sub_experiment_id":[
#                 "none"
#             ],
#             "tier":1
#         },
#         "ssp370-eas126aer":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "AER",
#                 "CHEM",
#                 "BGC"
#             ],
#             "description":"SSP3-7.0 anthropogenic emissions, but with East Asian anthropogenic aerosol and precursor emissions taken from SSP1-2.6. East Asia is the region bounded by 95 and 133E and 20 and 53N.",
#             "end":"2051",
#             "experiment":"SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and precursor emissions over East Asia",
#             "experiment_id":"ssp370-eas126aer",
#             "min_number_yrs_per_sim":37,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "historical"
#             ],
#             "required_model_components":[
#                 "AOGCM"
#             ],
#             "start":"2015",
#             "sub_experiment_id":[
#                 "none"
#             ],
#             "tier":1
#         },
#         "ssp370-sas126aer":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "AER",
#                 "CHEM",
#                 "BGC"
#             ],
#             "description":"SSP3-7.0 anthropogenic emissions, but with South Asian anthropogenic aerosol and precursor emissions taken from SSP1-2.6. South Asia is the region bounded by 65 and 95E and 5 and 35N.",
#             "end":"2051",
#             "experiment":"SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and precursor emissions over South Asia",
#             "experiment_id":"ssp370-sas126aer",
#             "min_number_yrs_per_sim":37,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "historical"
#             ],
#             "required_model_components":[
#                 "AOGCM"
#             ],
#             "start":"2015",
#             "sub_experiment_id":[
#                 "none"
#             ],
#             "tier": 1
#         },
#         "ssp370-afr126aer":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "AER",
#                 "CHEM",
#                 "BGC"
#             ],
#             "description":"SSP3-7.0 anthropogenic emissions, but with African and Middle Eastern anthropogenic aerosol and precursor emissions taken from SSP1-2.6. Africa and the Middle East is the region bounded by 20W, 60E, 35S and 35N.",
#             "end":"2051",
#             "experiment":"SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and precursor emissions over Africa and the Middle East",
#             "experiment_id":"ssp370-afr126aer",
#             "min_number_yrs_per_sim": 37,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "historical"
#             ],
#             "required_model_components":[
#                 "AOGCM"
#             ],
#             "start":"2015",
#             "sub_experiment_id":[
#                 "none"
#             ],
#             "tier": 1
#         },
#          "ssp370-nae126aer":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "AER",
#                 "CHEM",
#                 "BGC"
#             ],
#             "description":"SSP3-7.0 anthropogenic emissions, but with North American and European anthropogenic aerosol and precursor emissions taken from SSP1-2.6. North America and Europe are the regions bounded by 150W, 45W, 25N and 70N, and 20W, 45E, 35N and 70N.",
#             "end":"2051",
#             "experiment":"SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and precursor emissions over North America and Europe",
#             "experiment_id":"ssp370-nae126aer",
#             "min_number_yrs_per_sim": 37,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "historical"
#             ],
#             "required_model_components":[
#                 "AOGCM"
#             ],
#             "start":"2015",
#             "sub_experiment_id":[
#                 "none"
#             ],
#             "tier": 1
#         },
#         "ssp370-asia126aer":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "AER",
#                 "CHEM",
#                 "BGC"
#             ],
#             "description":"SSP3-7.0 anthropogenic emissions, but with Asian anthropogenic aerosol and precursor emissions taken from SSP1-2.6. Asia is defined as the combination of the East Asian and South Asian regions used in ssp370-eas126aer and ssp370-sas126aer. ",
#             "end":"2051",
#             "experiment":"SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and precursor emissions over Asia.",
#             "experiment_id":"ssp370-asia126aer",
#             "min_number_yrs_per_sim": 37,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "historical"
#             ],
#             "required_model_components":[
#                 "AOGCM"
#             ],
#             "start":"2015",
#             "sub_experiment_id":[
#                 "none"
#             ],
#             "tier":"2"
#         },
#         "ssp370-saf126ca":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "AER",
#                 "CHEM",
#                 "BGC"
#             ],
#             "description":"SSP3-7.0 anthropogenic emissions, but with sub-Saharan African black carbon and organic carbon emissions taken from SSP1-2.6. Sub-Saharan Africa is the region bounded by 20W, 50E, 35S, and 12N",
#             "end":"2051",
#             "experiment":"SSP3-7.0 forcing, but with SSP1-2.6 black carbon and organic carbon emissions over sub-Saharan Africa.",
#             "experiment_id":"ssp370-saf126ca",
#             "min_number_yrs_per_sim": 37,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "historical"
#             ],
#             "required_model_components":[
#                 "AOGCM"
#             ],
#             "start":"2015",
#             "sub_experiment_id":[
#                 "none"
#             ],
#             "tier":"2"
#         },
#         "ssp370-sas126ca":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "AER",
#                 "CHEM",
#                 "BGC"
#             ],
#             "description":"SSP3-7.0 anthropogenic emissions, but with South Asian black carbon and organic carbon emissions taken from SSP1-2.6. South Asia is the region bounded by 65 and 95E and 5 and 35N.",
#             "end":"2051",
#             "experiment":"SSP3-7.0 forcing, but with SSP1-2.6 black carbon and organic carbon emissions over South Asia.",
#             "experiment_id":"ssp370-sas126ca",
#             "min_number_yrs_per_sim": 37,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "historical"
#             ],
#             "required_model_components":[
#                 "AOGCM"
#             ],
#             "start":"2015",
#             "sub_experiment_id":[
#                 "none"
#             ],
#             "tier":"2"
#         },
#         "ssp370-126aer_nh3nox":{
#             "activity_id":[
#                 "RAMIP"
#             ],
#             "additional_allowed_model_components":[
#                 "AER",
#                 "CHEM",
#                 "BGC"
#             ],
#             "description":"SSP3-7.0 anthropogenic emissions, but anthropogenic aerosol and precursor emissions, including NH3 and NOx, taken from SSP1-2.6.",
#             "end":"2051",
#             "experiment":"SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and precursor emissions, including NH3 and NOx.",
#             "experiment_id":"ssp370-126aer_nh3nox",
#             "min_number_yrs_per_sim": 37,
#             "parent_activity_id":[
#                 "CMIP"
#             ],
#             "parent_experiment_id":[
#                 "historical"
#             ],
#             "required_model_components":[
#                 "AOGCM"
#             ],
#             "start":"2015",
#             "sub_experiment_id":[
#                 "none"
#             ],
#             "tier":"2"
#         }
#         }

# %%
# for i in data:
#     item = data[i]
#     item['@context'] = '_context_'
#     item['id'] = i.lower()
#     print(item)

#     item['model_realms'] = {**dict([[i.lower(),{"is_required":True}] for i in item['required_model_components']]),**dict([[i.lower(),{"is_required":False}] for i in item['additional_allowed_model_components']])}
#     del item['required_model_components'], item['additional_allowed_model_components']
    
#     item['name'] = item['experiment_id']
#     del item['experiment_id']
    
#     item['parameters'] = {
#         "end": item['end'], 
#         "start": item['start'],
#         "min_number_yrs_per_sim": item['min_number_yrs_per_sim'],
#         "id":"additional_parameters"
#     }    
    
#     del item['end'], item['start'], item['min_number_yrs_per_sim']
    
#     item['parent_activity'] = item['parent_activity_id']
#     item['parent_experiment'] = item['parent_experiment_id']
#     item['sub_experiment'] = item['sub_experiment_id']
    
#     del item['parent_activity_id'], item['parent_experiment_id'], item['sub_experiment_id']
    
#     pprint.pprint(item)
    
#     json.dump(item, open(f"./experiment/{i.lower()}.json", "w"), indent=4)
#     del item
# Out:
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['CHEM', 'BGC'], 'description': '', 'end': '2080', 'experiment': 'pre-industrial climatological SSTs and forcing, but with 2050 anthropogenic emissions from SSP3-7.0.', 'experiment_id': 'piClim-370', 'min_number_yrs_per_sim': 30, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['piControl'], 'required_model_components': ['AGCM', 'AER'], 'start': '2050', 'sub_experiment_id': ['none'], '@context': '_context_', 'id': 'piclim-370'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': '',
#  'experiment': 'pre-industrial climatological SSTs and forcing, but with 2050 '
#                'anthropogenic emissions from SSP3-7.0.',
#  'id': 'piclim-370',
#  'model_realms': {'aer': {'is_required': True},
#                   'agcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'piClim-370',
#  'parameters': {'end': '2080',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 30,
#                 'start': '2050'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['piControl'],
#  'sub_experiment': ['none']}
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['CHEM', 'BGC'], 'description': '', 'end': '2080', 'experiment': 'pre-industrial climatological SSTs and forcing, but with 2050 anthropogenic emissions. Aerosol and precursor emissions are taken from SSP1-2.6, while all other anthropogenic emissions follow SSP3-7.0.', 'experiment_id': 'piClim-370-126aer', 'min_number_yrs_per_sim': 30, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['piControl'], 'required_model_components': ['AGCM', 'AER'], 'start': '2050', 'sub_experiment_id': ['none'], '@context': '_context_', 'id': 'piclim-370-126aer'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': '',
#  'experiment': 'pre-industrial climatological SSTs and forcing, but with 2050 '
#                'anthropogenic emissions. Aerosol and precursor emissions are '
#                'taken from SSP1-2.6, while all other anthropogenic emissions '
#                'follow SSP3-7.0.',
#  'id': 'piclim-370-126aer',
#  'model_realms': {'aer': {'is_required': True},
#                   'agcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'piClim-370-126aer',
#  'parameters': {'end': '2080',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 30,
#                 'start': '2050'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['piControl'],
#  'sub_experiment': ['none']}
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['CHEM', 'BGC'], 'description': '', 'end': '2080', 'experiment': 'pre-industrial climatological SSTs and forcing, but with 2050 anthropogenic emissions. Aerosol and precursor emissions over East Asia are taken from SSP1-2.6, while all other anthropogenic emissions follow SSP3-7.0.', 'experiment_id': 'piClim-370-eas126aer', 'min_number_yrs_per_sim': 30, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['piControl'], 'required_model_components': ['AGCM', 'AER'], 'start': '2050', 'sub_experiment_id': ['none'], '@context': '_context_', 'id': 'piclim-370-eas126aer'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': '',
#  'experiment': 'pre-industrial climatological SSTs and forcing, but with 2050 '
#                'anthropogenic emissions. Aerosol and precursor emissions over '
#                'East Asia are taken from SSP1-2.6, while all other '
#                'anthropogenic emissions follow SSP3-7.0.',
#  'id': 'piclim-370-eas126aer',
#  'model_realms': {'aer': {'is_required': True},
#                   'agcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'piClim-370-eas126aer',
#  'parameters': {'end': '2080',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 30,
#                 'start': '2050'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['piControl'],
#  'sub_experiment': ['none']}
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['CHEM', 'BGC'], 'description': '', 'end': '2080', 'experiment': 'pre-industrial climatological SSTs and forcing, but with 2050 anthropogenic emissions. Aerosol and precursor emissions over South Asia are taken from SSP1-2.6, while all other anthropogenic emissions follow SSP3-7.0.', 'experiment_id': 'piClim-370-sas126aer', 'min_number_yrs_per_sim': 30, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['piControl'], 'required_model_components': ['AGCM', 'AER'], 'start': '2050', 'sub_experiment_id': ['none'], '@context': '_context_', 'id': 'piclim-370-sas126aer'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': '',
#  'experiment': 'pre-industrial climatological SSTs and forcing, but with 2050 '
#                'anthropogenic emissions. Aerosol and precursor emissions over '
#                'South Asia are taken from SSP1-2.6, while all other '
#                'anthropogenic emissions follow SSP3-7.0.',
#  'id': 'piclim-370-sas126aer',
#  'model_realms': {'aer': {'is_required': True},
#                   'agcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'piClim-370-sas126aer',
#  'parameters': {'end': '2080',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 30,
#                 'start': '2050'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['piControl'],
#  'sub_experiment': ['none']}
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['CHEM', 'BGC'], 'description': '', 'end': '2080', 'experiment': 'pre-industrial climatological SSTs and forcing, but with 2050 anthropogenic emissions. Aerosol and precursor emissions over Africa and the Middle East are taken from SSP1-2.6, while all other anthropogenic emissions follow SSP3-7.0.', 'experiment_id': 'piClim-370-afr126aer', 'min_number_yrs_per_sim': 30, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['piControl'], 'required_model_components': ['AGCM', 'AER'], 'start': '2050', 'sub_experiment_id': ['none'], '@context': '_context_', 'id': 'piclim-370-afr126aer'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': '',
#  'experiment': 'pre-industrial climatological SSTs and forcing, but with 2050 '
#                'anthropogenic emissions. Aerosol and precursor emissions over '
#                'Africa and the Middle East are taken from SSP1-2.6, while all '
#                'other anthropogenic emissions follow SSP3-7.0.',
#  'id': 'piclim-370-afr126aer',
#  'model_realms': {'aer': {'is_required': True},
#                   'agcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'piClim-370-afr126aer',
#  'parameters': {'end': '2080',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 30,
#                 'start': '2050'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['piControl'],
#  'sub_experiment': ['none']}
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['CHEM', 'BGC'], 'description': '', 'end': '2080', 'experiment': 'pre-industrial climatological SSTs and forcing, but with 2050 anthropogenic emissions. Aerosol and precursor emissions over North America and Europe are taken from SSP1-2.6, while all other anthropogenic emissions follow SSP3-7.0.', 'experiment_id': 'piClim-370-nae126aer', 'min_number_yrs_per_sim': 30, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['piControl'], 'required_model_components': ['AGCM', 'AER'], 'start': '2050', 'sub_experiment_id': ['none'], '@context': '_context_', 'id': 'piclim-370-nae126aer'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': '',
#  'experiment': 'pre-industrial climatological SSTs and forcing, but with 2050 '
#                'anthropogenic emissions. Aerosol and precursor emissions over '
#                'North America and Europe are taken from SSP1-2.6, while all '
#                'other anthropogenic emissions follow SSP3-7.0.',
#  'id': 'piclim-370-nae126aer',
#  'model_realms': {'aer': {'is_required': True},
#                   'agcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'piClim-370-nae126aer',
#  'parameters': {'end': '2080',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 30,
#                 'start': '2050'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['piControl'],
#  'sub_experiment': ['none']}
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['CHEM', 'BGC'], 'description': '', 'end': '2080', 'experiment': 'pre-industrial climatological SSTs and forcing, but with 2050 anthropogenic emissions. Aerosol and precursor emissions, including NH3 and NOx, are taken from SSP1-2.6, while all other anthropogenic emissions follow SSP3-7.0.', 'experiment_id': 'piClim-370-126aer_nh3nox', 'min_number_yrs_per_sim': 30, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['piControl'], 'required_model_components': ['AGCM', 'AER'], 'start': '2050', 'sub_experiment_id': ['none'], '@context': '_context_', 'id': 'piclim-370-126aer_nh3nox'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': '',
#  'experiment': 'pre-industrial climatological SSTs and forcing, but with 2050 '
#                'anthropogenic emissions. Aerosol and precursor emissions, '
#                'including NH3 and NOx, are taken from SSP1-2.6, while all '
#                'other anthropogenic emissions follow SSP3-7.0.',
#  'id': 'piclim-370-126aer_nh3nox',
#  'model_realms': {'aer': {'is_required': True},
#                   'agcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'piClim-370-126aer_nh3nox',
#  'parameters': {'end': '2080',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 30,
#                 'start': '2050'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['piControl'],
#  'sub_experiment': ['none']}
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['AER', 'CHEM', 'BGC'], 'description': 'SSP3-7.0 anthropogenic emissions, but with anthropogenic aerosol and precursor emissions taken from SSP1-2.6.', 'end': '2051', 'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and precursor emissions', 'experiment_id': 'ssp370-126aer', 'min_number_yrs_per_sim': 37, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['historical'], 'required_model_components': ['AOGCM'], 'start': '2015', 'sub_experiment_id': ['none'], 'tier': 1, '@context': '_context_', 'id': 'ssp370-126aer'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': 'SSP3-7.0 anthropogenic emissions, but with anthropogenic '
#                 'aerosol and precursor emissions taken from SSP1-2.6.',
#  'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and '
#                'precursor emissions',
#  'id': 'ssp370-126aer',
#  'model_realms': {'aer': {'is_required': False},
#                   'aogcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'ssp370-126aer',
#  'parameters': {'end': '2051',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 37,
#                 'start': '2015'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['historical'],
#  'sub_experiment': ['none'],
#  'tier': 1}
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['AER', 'CHEM', 'BGC'], 'description': 'SSP3-7.0 anthropogenic emissions, but with East Asian anthropogenic aerosol and precursor emissions taken from SSP1-2.6. East Asia is the region bounded by 95 and 133E and 20 and 53N.', 'end': '2051', 'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and precursor emissions over East Asia', 'experiment_id': 'ssp370-eas126aer', 'min_number_yrs_per_sim': 37, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['historical'], 'required_model_components': ['AOGCM'], 'start': '2015', 'sub_experiment_id': ['none'], 'tier': 1, '@context': '_context_', 'id': 'ssp370-eas126aer'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': 'SSP3-7.0 anthropogenic emissions, but with East Asian '
#                 'anthropogenic aerosol and precursor emissions taken from '
#                 'SSP1-2.6. East Asia is the region bounded by 95 and 133E and '
#                 '20 and 53N.',
#  'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and '
#                'precursor emissions over East Asia',
#  'id': 'ssp370-eas126aer',
#  'model_realms': {'aer': {'is_required': False},
#                   'aogcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'ssp370-eas126aer',
#  'parameters': {'end': '2051',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 37,
#                 'start': '2015'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['historical'],
#  'sub_experiment': ['none'],
#  'tier': 1}
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['AER', 'CHEM', 'BGC'], 'description': 'SSP3-7.0 anthropogenic emissions, but with South Asian anthropogenic aerosol and precursor emissions taken from SSP1-2.6. South Asia is the region bounded by 65 and 95E and 5 and 35N.', 'end': '2051', 'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and precursor emissions over South Asia', 'experiment_id': 'ssp370-sas126aer', 'min_number_yrs_per_sim': 37, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['historical'], 'required_model_components': ['AOGCM'], 'start': '2015', 'sub_experiment_id': ['none'], 'tier': 1, '@context': '_context_', 'id': 'ssp370-sas126aer'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': 'SSP3-7.0 anthropogenic emissions, but with South Asian '
#                 'anthropogenic aerosol and precursor emissions taken from '
#                 'SSP1-2.6. South Asia is the region bounded by 65 and 95E and '
#                 '5 and 35N.',
#  'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and '
#                'precursor emissions over South Asia',
#  'id': 'ssp370-sas126aer',
#  'model_realms': {'aer': {'is_required': False},
#                   'aogcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'ssp370-sas126aer',
#  'parameters': {'end': '2051',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 37,
#                 'start': '2015'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['historical'],
#  'sub_experiment': ['none'],
#  'tier': 1}
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['AER', 'CHEM', 'BGC'], 'description': 'SSP3-7.0 anthropogenic emissions, but with African and Middle Eastern anthropogenic aerosol and precursor emissions taken from SSP1-2.6. Africa and the Middle East is the region bounded by 20W, 60E, 35S and 35N.', 'end': '2051', 'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and precursor emissions over Africa and the Middle East', 'experiment_id': 'ssp370-afr126aer', 'min_number_yrs_per_sim': 37, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['historical'], 'required_model_components': ['AOGCM'], 'start': '2015', 'sub_experiment_id': ['none'], 'tier': 1, '@context': '_context_', 'id': 'ssp370-afr126aer'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': 'SSP3-7.0 anthropogenic emissions, but with African and Middle '
#                 'Eastern anthropogenic aerosol and precursor emissions taken '
#                 'from SSP1-2.6. Africa and the Middle East is the region '
#                 'bounded by 20W, 60E, 35S and 35N.',
#  'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and '
#                'precursor emissions over Africa and the Middle East',
#  'id': 'ssp370-afr126aer',
#  'model_realms': {'aer': {'is_required': False},
#                   'aogcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'ssp370-afr126aer',
#  'parameters': {'end': '2051',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 37,
#                 'start': '2015'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['historical'],
#  'sub_experiment': ['none'],
#  'tier': 1}
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['AER', 'CHEM', 'BGC'], 'description': 'SSP3-7.0 anthropogenic emissions, but with North American and European anthropogenic aerosol and precursor emissions taken from SSP1-2.6. North America and Europe are the regions bounded by 150W, 45W, 25N and 70N, and 20W, 45E, 35N and 70N.', 'end': '2051', 'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and precursor emissions over North America and Europe', 'experiment_id': 'ssp370-nae126aer', 'min_number_yrs_per_sim': 37, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['historical'], 'required_model_components': ['AOGCM'], 'start': '2015', 'sub_experiment_id': ['none'], 'tier': 1, '@context': '_context_', 'id': 'ssp370-nae126aer'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': 'SSP3-7.0 anthropogenic emissions, but with North American and '
#                 'European anthropogenic aerosol and precursor emissions taken '
#                 'from SSP1-2.6. North America and Europe are the regions '
#                 'bounded by 150W, 45W, 25N and 70N, and 20W, 45E, 35N and 70N.',
#  'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and '
#                'precursor emissions over North America and Europe',
#  'id': 'ssp370-nae126aer',
#  'model_realms': {'aer': {'is_required': False},
#                   'aogcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'ssp370-nae126aer',
#  'parameters': {'end': '2051',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 37,
#                 'start': '2015'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['historical'],
#  'sub_experiment': ['none'],
#  'tier': 1}
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['AER', 'CHEM', 'BGC'], 'description': 'SSP3-7.0 anthropogenic emissions, but with Asian anthropogenic aerosol and precursor emissions taken from SSP1-2.6. Asia is defined as the combination of the East Asian and South Asian regions used in ssp370-eas126aer and ssp370-sas126aer. ', 'end': '2051', 'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and precursor emissions over Asia.', 'experiment_id': 'ssp370-asia126aer', 'min_number_yrs_per_sim': 37, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['historical'], 'required_model_components': ['AOGCM'], 'start': '2015', 'sub_experiment_id': ['none'], 'tier': '2', '@context': '_context_', 'id': 'ssp370-asia126aer'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': 'SSP3-7.0 anthropogenic emissions, but with Asian '
#                 'anthropogenic aerosol and precursor emissions taken from '
#                 'SSP1-2.6. Asia is defined as the combination of the East '
#                 'Asian and South Asian regions used in ssp370-eas126aer and '
#                 'ssp370-sas126aer. ',
#  'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and '
#                'precursor emissions over Asia.',
#  'id': 'ssp370-asia126aer',
#  'model_realms': {'aer': {'is_required': False},
#                   'aogcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'ssp370-asia126aer',
#  'parameters': {'end': '2051',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 37,
#                 'start': '2015'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['historical'],
#  'sub_experiment': ['none'],
#  'tier': '2'}
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['AER', 'CHEM', 'BGC'], 'description': 'SSP3-7.0 anthropogenic emissions, but with sub-Saharan African black carbon and organic carbon emissions taken from SSP1-2.6. Sub-Saharan Africa is the region bounded by 20W, 50E, 35S, and 12N', 'end': '2051', 'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 black carbon and organic carbon emissions over sub-Saharan Africa.', 'experiment_id': 'ssp370-saf126ca', 'min_number_yrs_per_sim': 37, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['historical'], 'required_model_components': ['AOGCM'], 'start': '2015', 'sub_experiment_id': ['none'], 'tier': '2', '@context': '_context_', 'id': 'ssp370-saf126ca'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': 'SSP3-7.0 anthropogenic emissions, but with sub-Saharan '
#                 'African black carbon and organic carbon emissions taken from '
#                 'SSP1-2.6. Sub-Saharan Africa is the region bounded by 20W, '
#                 '50E, 35S, and 12N',
#  'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 black carbon and organic '
#                'carbon emissions over sub-Saharan Africa.',
#  'id': 'ssp370-saf126ca',
#  'model_realms': {'aer': {'is_required': False},
#                   'aogcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'ssp370-saf126ca',
#  'parameters': {'end': '2051',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 37,
#                 'start': '2015'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['historical'],
#  'sub_experiment': ['none'],
#  'tier': '2'}
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['AER', 'CHEM', 'BGC'], 'description': 'SSP3-7.0 anthropogenic emissions, but with South Asian black carbon and organic carbon emissions taken from SSP1-2.6. South Asia is the region bounded by 65 and 95E and 5 and 35N.', 'end': '2051', 'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 black carbon and organic carbon emissions over South Asia.', 'experiment_id': 'ssp370-sas126ca', 'min_number_yrs_per_sim': 37, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['historical'], 'required_model_components': ['AOGCM'], 'start': '2015', 'sub_experiment_id': ['none'], 'tier': '2', '@context': '_context_', 'id': 'ssp370-sas126ca'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': 'SSP3-7.0 anthropogenic emissions, but with South Asian black '
#                 'carbon and organic carbon emissions taken from SSP1-2.6. '
#                 'South Asia is the region bounded by 65 and 95E and 5 and 35N.',
#  'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 black carbon and organic '
#                'carbon emissions over South Asia.',
#  'id': 'ssp370-sas126ca',
#  'model_realms': {'aer': {'is_required': False},
#                   'aogcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'ssp370-sas126ca',
#  'parameters': {'end': '2051',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 37,
#                 'start': '2015'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['historical'],
#  'sub_experiment': ['none'],
#  'tier': '2'}
# {'activity_id': ['RAMIP'], 'additional_allowed_model_components': ['AER', 'CHEM', 'BGC'], 'description': 'SSP3-7.0 anthropogenic emissions, but anthropogenic aerosol and precursor emissions, including NH3 and NOx, taken from SSP1-2.6.', 'end': '2051', 'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and precursor emissions, including NH3 and NOx.', 'experiment_id': 'ssp370-126aer_nh3nox', 'min_number_yrs_per_sim': 37, 'parent_activity_id': ['CMIP'], 'parent_experiment_id': ['historical'], 'required_model_components': ['AOGCM'], 'start': '2015', 'sub_experiment_id': ['none'], 'tier': '2', '@context': '_context_', 'id': 'ssp370-126aer_nh3nox'}
# {'@context': '_context_',
#  'activity_id': ['RAMIP'],
#  'description': 'SSP3-7.0 anthropogenic emissions, but anthropogenic aerosol '
#                 'and precursor emissions, including NH3 and NOx, taken from '
#                 'SSP1-2.6.',
#  'experiment': 'SSP3-7.0 forcing, but with SSP1-2.6 anthropogenic aerosol and '
#                'precursor emissions, including NH3 and NOx.',
#  'id': 'ssp370-126aer_nh3nox',
#  'model_realms': {'aer': {'is_required': False},
#                   'aogcm': {'is_required': True},
#                   'bgc': {'is_required': False},
#                   'chem': {'is_required': False}},
#  'name': 'ssp370-126aer_nh3nox',
#  'parameters': {'end': '2051',
#                 'id': 'additional_parameters',
#                 'min_number_yrs_per_sim': 37,
#                 'start': '2015'},
#  'parent_activity': ['CMIP'],
#  'parent_experiment': ['historical'],
#  'sub_experiment': ['none'],
#  'tier': '2'}

# %%
# !ls
# Out:
# _context_        experiment       project
# component        graph.jsonld     source
# del.ipynb        graph.min.jsonld sub_experiment
